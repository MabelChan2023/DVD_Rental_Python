# %%
import pandas as pd
import transformers
from transformers import pipeline

# %%
model_id = "cardiffnlp/twitter-roberta-base-sentiment-latest"
label = pipeline('sentiment-analysis', model = model_id)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# Some layers of TFRobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
df = pd.read_csv('film_description.csv')

# %%
text_to_Analysis = df.description
result=[]
for text in text_to_Analysis:
    result.append(label(text))

# %%
result
# Out:
# [[{'label': 'positive', 'score': 0.36934182047843933}],
#  [{'label': 'positive', 'score': 0.3896864056587219}],
#  [{'label': 'positive', 'score': 0.40503770112991333}],
#  [{'label': 'positive', 'score': 0.4037313759326935}],
#  [{'label': 'positive', 'score': 0.40603315830230713}],
#  [{'label': 'positive', 'score': 0.41587144136428833}],
#  [{'label': 'positive', 'score': 0.3834754228591919}],
#  [{'label': 'positive', 'score': 0.3714103698730469}],
#  [{'label': 'positive', 'score': 0.39021825790405273}],
#  [{'label': 'positive', 'score': 0.4038068950176239}],
#  [{'label': 'positive', 'score': 0.3994949162006378}],
#  [{'label': 'positive', 'score': 0.37979787588119507}],
#  [{'label': 'positive', 'score': 0.40936315059661865}],
#  [{'label': 'positive', 'score': 0.40962913632392883}],
#  [{'label': 'positive', 'score': 0.400534987449646}],
#  [{'label': 'positive', 'score': 0.41429516673088074}],
#  [{'label': 'positive', 'score': 0.417261004447937}],
#  [{'label': 'positive', 'score': 0.41038185358047485}],
#  [{'label': 'positive', 'score': 0.36971086263656616}],
#  [{'label': 'positive', 'score': 0.42148134112358093}],
#  [{'label': 'positive', 'score': 0.3890638053417206}],
#  [{'label': 'positive', 'score': 0.4111182391643524}],
#  [{'label': 'positive', 'score': 0.3941565752029419}],
#  [{'label': 'positive', 'score': 0.4279731810092926}],
#  [{'label': 'positive', 'score': 0.3990631103515625}],
#  [{'label': 'positive', 'score': 0.3766768276691437}],
#  [{'label': 'positive', 'score': 0.4176395535469055}],
#  [{'label': 'positive', 'score': 0.3862879276275635}],
#  [{'label': 'positive', 'score': 0.37368595600128174}],
#  [{'label': 'positive', 'score': 0.37706950306892395}],
#  [{'label': 'positive', 'score': 0.38320618867874146}],
#  [{'label': 'positive', 'score': 0.3788316547870636}],
#  [{'label': 'positive', 'score': 0.4032241404056549}],
#  [{'label': 'positive', 'score': 0.3951925039291382}],
#  [{'label': 'positive', 'score': 0.37203967571258545}],
#  [{'label': 'positive', 'score': 0.42211195826530457}],
#  [{'label': 'positive', 'score': 0.3897363245487213}],
#  [{'label': 'positive', 'score': 0.4083147644996643}],
#  [{'label': 'positive', 'score': 0.40055203437805176}],
#  [{'label': 'positive', 'score': 0.3966192305088043}],
#  [{'label': 'negative', 'score': 0.3579046428203583}],
#  [{'label': 'negative', 'score': 0.3723367750644684}],
#  [{'label': 'positive', 'score': 0.39594635367393494}],
#  [{'label': 'positive', 'score': 0.42763081192970276}],
#  [{'label': 'negative', 'score': 0.38041189312934875}],
#  [{'label': 'positive', 'score': 0.3769287168979645}],
#  [{'label': 'positive', 'score': 0.40002793073654175}],
#  [{'label': 'positive', 'score': 0.3982335329055786}],
#  [{'label': 'positive', 'score': 0.39989691972732544}],
#  [{'label': 'positive', 'score': 0.39089304208755493}],
#  [{'label': 'positive', 'score': 0.38337242603302}],
#  [{'label': 'positive', 'score': 0.4195035994052887}],
#  [{'label': 'positive', 'score': 0.3791870176792145}],
#  [{'label': 'positive', 'score': 0.38777706027030945}],
#  [{'label': 'positive', 'score': 0.3893134891986847}],
#  [{'label': 'positive', 'score': 0.3790252208709717}],
#  [{'label': 'positive', 'score': 0.38207605481147766}],
#  [{'label': 'positive', 'score': 0.3762257993221283}],
#  [{'label': 'positive', 'score': 0.3985486924648285}],
#  [{'label': 'positive', 'score': 0.3890012800693512}],
#  [{'label': 'positive', 'score': 0.39772850275039673}],
#  [{'label': 'positive', 'score': 0.41630256175994873}],
#  [{'label': 'positive', 'score': 0.37408193945884705}],
#  [{'label': 'positive', 'score': 0.38821113109588623}],
#  [{'label': 'positive', 'score': 0.4261550307273865}],
#  [{'label': 'positive', 'score': 0.38681086897850037}],
#  [{'label': 'positive', 'score': 0.3848326802253723}],
#  [{'label': 'positive', 'score': 0.38729530572891235}],
#  [{'label': 'positive', 'score': 0.38982731103897095}],
#  [{'label': 'negative', 'score': 0.37103673815727234}],
#  [{'label': 'positive', 'score': 0.38480961322784424}],
#  [{'label': 'positive', 'score': 0.39799341559410095}],
#  [{'label': 'positive', 'score': 0.4311583340167999}],
#  [{'label': 'positive', 'score': 0.3760479688644409}],
#  [{'label': 'positive', 'score': 0.38996997475624084}],
#  [{'label': 'positive', 'score': 0.4139847755432129}],
#  [{'label': 'positive', 'score': 0.4012465476989746}],
#  [{'label': 'positive', 'score': 0.39950135350227356}],
#  [{'label': 'positive', 'score': 0.40596532821655273}],
#  [{'label': 'negative', 'score': 0.368478387594223}],
#  [{'label': 'positive', 'score': 0.3613937199115753}],
#  [{'label': 'positive', 'score': 0.4273850619792938}],
#  [{'label': 'positive', 'score': 0.422401487827301}],
#  [{'label': 'positive', 'score': 0.406827449798584}],
#  [{'label': 'positive', 'score': 0.38738957047462463}],
#  [{'label': 'positive', 'score': 0.38633620738983154}],
#  [{'label': 'positive', 'score': 0.3940650522708893}],
#  [{'label': 'positive', 'score': 0.42559540271759033}],
#  [{'label': 'positive', 'score': 0.3678244650363922}],
#  [{'label': 'positive', 'score': 0.39870214462280273}],
#  [{'label': 'positive', 'score': 0.42381685972213745}],
#  [{'label': 'positive', 'score': 0.40262654423713684}],
#  [{'label': 'positive', 'score': 0.4122017025947571}],
#  [{'label': 'positive', 'score': 0.37958839535713196}],
#  [{'label': 'positive', 'score': 0.36095720529556274}],
#  [{'label': 'positive', 'score': 0.39581596851348877}],
#  [{'label': 'positive', 'score': 0.39862385392189026}],
#  [{'label': 'positive', 'score': 0.3970479965209961}],
#  [{'label': 'positive', 'score': 0.36875754594802856}],
#  [{'label': 'positive', 'score': 0.3898376524448395}],
#  [{'label': 'negative', 'score': 0.3800002336502075}],
#  [{'label': 'positive', 'score': 0.37043219804763794}],
#  [{'label': 'positive', 'score': 0.4264523983001709}],
#  [{'label': 'positive', 'score': 0.40503713488578796}],
#  [{'label': 'positive', 'score': 0.3623523712158203}],
#  [{'label': 'positive', 'score': 0.3861655592918396}],
#  [{'label': 'positive', 'score': 0.40358424186706543}],
#  [{'label': 'negative', 'score': 0.356015145778656}],
#  [{'label': 'positive', 'score': 0.4000098407268524}],
#  [{'label': 'positive', 'score': 0.3997727036476135}],
#  [{'label': 'negative', 'score': 0.3637649118900299}],
#  [{'label': 'positive', 'score': 0.4207667112350464}],
#  [{'label': 'positive', 'score': 0.4121992588043213}],
#  [{'label': 'positive', 'score': 0.3887498080730438}],
#  [{'label': 'positive', 'score': 0.3654593229293823}],
#  [{'label': 'positive', 'score': 0.38812753558158875}],
#  [{'label': 'positive', 'score': 0.4007800221443176}],
#  [{'label': 'positive', 'score': 0.430328905582428}],
#  [{'label': 'positive', 'score': 0.3848166763782501}],
#  [{'label': 'positive', 'score': 0.4153822362422943}],
#  [{'label': 'positive', 'score': 0.36820295453071594}],
#  [{'label': 'positive', 'score': 0.37755143642425537}],
#  [{'label': 'positive', 'score': 0.38813018798828125}],
#  [{'label': 'positive', 'score': 0.40938010811805725}],
#  [{'label': 'positive', 'score': 0.40199124813079834}],
#  [{'label': 'positive', 'score': 0.36817124485969543}],
#  [{'label': 'positive', 'score': 0.37509286403656006}],
#  [{'label': 'positive', 'score': 0.41398176550865173}],
#  [{'label': 'positive', 'score': 0.40989938378334045}],
#  [{'label': 'positive', 'score': 0.4215179979801178}],
#  [{'label': 'positive', 'score': 0.41613733768463135}],
#  [{'label': 'positive', 'score': 0.4081476032733917}],
#  [{'label': 'positive', 'score': 0.41571730375289917}],
#  [{'label': 'positive', 'score': 0.3766135573387146}],
#  [{'label': 'negative', 'score': 0.3722781240940094}],
#  [{'label': 'positive', 'score': 0.3614535927772522}],
#  [{'label': 'positive', 'score': 0.4088984727859497}],
#  [{'label': 'positive', 'score': 0.41181543469429016}],
#  [{'label': 'positive', 'score': 0.3707033097743988}],
#  [{'label': 'positive', 'score': 0.41158828139305115}],
#  [{'label': 'positive', 'score': 0.3874651789665222}],
#  [{'label': 'positive', 'score': 0.41280195116996765}],
#  [{'label': 'positive', 'score': 0.42143502831459045}],
#  [{'label': 'positive', 'score': 0.39268776774406433}],
#  [{'label': 'positive', 'score': 0.41021642088890076}],
#  [{'label': 'positive', 'score': 0.4183776378631592}],
#  [{'label': 'positive', 'score': 0.4008219838142395}],
#  [{'label': 'positive', 'score': 0.367767333984375}],
#  [{'label': 'positive', 'score': 0.3776495158672333}],
#  [{'label': 'positive', 'score': 0.41901063919067383}],
#  [{'label': 'positive', 'score': 0.40598979592323303}],
#  [{'label': 'positive', 'score': 0.4028245210647583}],
#  [{'label': 'positive', 'score': 0.4179794192314148}],
#  [{'label': 'negative', 'score': 0.3939253091812134}],
#  [{'label': 'positive', 'score': 0.38249000906944275}],
#  [{'label': 'positive', 'score': 0.3910045623779297}],
#  [{'label': 'positive', 'score': 0.3914918601512909}],
#  [{'label': 'positive', 'score': 0.38891297578811646}],
#  [{'label': 'positive', 'score': 0.3603571951389313}],
#  [{'label': 'positive', 'score': 0.3722330927848816}],
#  [{'label': 'positive', 'score': 0.37600964307785034}],
#  [{'label': 'positive', 'score': 0.3867425322532654}],
#  [{'label': 'positive', 'score': 0.3993469178676605}],
#  [{'label': 'positive', 'score': 0.39719370007514954}],
#  [{'label': 'positive', 'score': 0.38563239574432373}],
#  [{'label': 'positive', 'score': 0.3630973994731903}],
#  [{'label': 'positive', 'score': 0.3888164758682251}],
#  [{'label': 'positive', 'score': 0.40110036730766296}],
#  [{'label': 'positive', 'score': 0.35591185092926025}],
#  [{'label': 'positive', 'score': 0.3809071183204651}],
#  [{'label': 'positive', 'score': 0.3900656998157501}],
#  [{'label': 'positive', 'score': 0.4025329649448395}],
#  [{'label': 'positive', 'score': 0.3797483444213867}],
#  [{'label': 'positive', 'score': 0.4078567326068878}],
#  [{'label': 'positive', 'score': 0.394383043050766}],
#  [{'label': 'positive', 'score': 0.39794889092445374}],
#  [{'label': 'positive', 'score': 0.40236642956733704}],
#  [{'label': 'positive', 'score': 0.3749401867389679}],
#  [{'label': 'positive', 'score': 0.3891507685184479}],
#  [{'label': 'negative', 'score': 0.3681502938270569}],
#  [{'label': 'positive', 'score': 0.4079572856426239}],
#  [{'label': 'positive', 'score': 0.39092618227005005}],
#  [{'label': 'positive', 'score': 0.39210909605026245}],
#  [{'label': 'positive', 'score': 0.3965857923030853}],
#  [{'label': 'positive', 'score': 0.39504870772361755}],
#  [{'label': 'positive', 'score': 0.3932047486305237}],
#  [{'label': 'positive', 'score': 0.3932417929172516}],
#  [{'label': 'positive', 'score': 0.39790940284729004}],
#  [{'label': 'positive', 'score': 0.4016629457473755}],
#  [{'label': 'positive', 'score': 0.3889472782611847}],
#  [{'label': 'positive', 'score': 0.39756399393081665}],
#  [{'label': 'positive', 'score': 0.4161998927593231}],
#  [{'label': 'positive', 'score': 0.375155508518219}],
#  [{'label': 'positive', 'score': 0.4122610092163086}],
#  [{'label': 'negative', 'score': 0.3695783317089081}],
#  [{'label': 'positive', 'score': 0.38836178183555603}],
#  [{'label': 'positive', 'score': 0.3795211613178253}],
#  [{'label': 'positive', 'score': 0.39410096406936646}],
#  [{'label': 'positive', 'score': 0.37681713700294495}],
#  [{'label': 'positive', 'score': 0.40011924505233765}],
#  [{'label': 'positive', 'score': 0.40500426292419434}],
#  [{'label': 'positive', 'score': 0.3864785432815552}],
#  [{'label': 'positive', 'score': 0.40060800313949585}],
#  [{'label': 'positive', 'score': 0.4134136736392975}],
#  [{'label': 'positive', 'score': 0.403801828622818}],
#  [{'label': 'positive', 'score': 0.41931813955307007}],
#  [{'label': 'positive', 'score': 0.41074398159980774}],
#  [{'label': 'positive', 'score': 0.3907725214958191}],
#  [{'label': 'positive', 'score': 0.3883531987667084}],
#  [{'label': 'positive', 'score': 0.39739373326301575}],
#  [{'label': 'positive', 'score': 0.41135814785957336}],
#  [{'label': 'positive', 'score': 0.3910388946533203}],
#  [{'label': 'positive', 'score': 0.36326032876968384}],
#  [{'label': 'negative', 'score': 0.35410138964653015}],
#  [{'label': 'positive', 'score': 0.39764225482940674}],
#  [{'label': 'positive', 'score': 0.37671196460723877}],
#  [{'label': 'positive', 'score': 0.38188496232032776}],
#  [{'label': 'positive', 'score': 0.3628852367401123}],
#  [{'label': 'positive', 'score': 0.41662004590034485}],
#  [{'label': 'positive', 'score': 0.42270323634147644}],
#  [{'label': 'positive', 'score': 0.3833559453487396}],
#  [{'label': 'positive', 'score': 0.39424943923950195}],
#  [{'label': 'positive', 'score': 0.4051940441131592}],
#  [{'label': 'positive', 'score': 0.36168015003204346}],
#  [{'label': 'positive', 'score': 0.41924694180488586}],
#  [{'label': 'positive', 'score': 0.40166565775871277}],
#  [{'label': 'negative', 'score': 0.3765590786933899}],
#  [{'label': 'positive', 'score': 0.3994104266166687}],
#  [{'label': 'positive', 'score': 0.39612096548080444}],
#  [{'label': 'positive', 'score': 0.376308798789978}],
#  [{'label': 'negative', 'score': 0.3759666383266449}],
#  [{'label': 'positive', 'score': 0.392939954996109}],
#  [{'label': 'positive', 'score': 0.41237518191337585}],
#  [{'label': 'positive', 'score': 0.39650067687034607}],
#  [{'label': 'positive', 'score': 0.3716888427734375}],
#  [{'label': 'positive', 'score': 0.3927108943462372}],
#  [{'label': 'positive', 'score': 0.4243481159210205}],
#  [{'label': 'positive', 'score': 0.4130038917064667}],
#  [{'label': 'positive', 'score': 0.41467010974884033}],
#  [{'label': 'positive', 'score': 0.3955061435699463}],
#  [{'label': 'positive', 'score': 0.374283105134964}],
#  [{'label': 'positive', 'score': 0.364452987909317}],
#  [{'label': 'positive', 'score': 0.4032425582408905}],
#  [{'label': 'positive', 'score': 0.39761748909950256}],
#  [{'label': 'positive', 'score': 0.3644392192363739}],
#  [{'label': 'positive', 'score': 0.3888384699821472}],
#  [{'label': 'positive', 'score': 0.38348257541656494}],
#  [{'label': 'positive', 'score': 0.41697028279304504}],
#  [{'label': 'positive', 'score': 0.4208272099494934}],
#  [{'label': 'positive', 'score': 0.40528106689453125}],
#  [{'label': 'positive', 'score': 0.3770042061805725}],
#  [{'label': 'positive', 'score': 0.40606752038002014}],
#  [{'label': 'positive', 'score': 0.4311383068561554}],
#  [{'label': 'positive', 'score': 0.37641552090644836}],
#  [{'label': 'positive', 'score': 0.3926592171192169}],
#  [{'label': 'positive', 'score': 0.39985403418540955}],
#  [{'label': 'positive', 'score': 0.403662770986557}],
#  [{'label': 'positive', 'score': 0.3892548084259033}],
#  [{'label': 'positive', 'score': 0.372609943151474}],
#  [{'label': 'positive', 'score': 0.38932499289512634}],
#  [{'label': 'positive', 'score': 0.39558082818984985}],
#  [{'label': 'negative', 'score': 0.3729681968688965}],
#  [{'label': 'positive', 'score': 0.38374558091163635}],
#  [{'label': 'negative', 'score': 0.37145063281059265}],
#  [{'label': 'positive', 'score': 0.35941267013549805}],
#  [{'label': 'positive', 'score': 0.404222697019577}],
#  [{'label': 'positive', 'score': 0.4004518687725067}],
#  [{'label': 'positive', 'score': 0.40083009004592896}],
#  [{'label': 'positive', 'score': 0.36141684651374817}],
#  [{'label': 'negative', 'score': 0.3830052614212036}],
#  [{'label': 'positive', 'score': 0.3772985637187958}],
#  [{'label': 'positive', 'score': 0.39648985862731934}],
#  [{'label': 'negative', 'score': 0.3672584891319275}],
#  [{'label': 'negative', 'score': 0.3576791286468506}],
#  [{'label': 'negative', 'score': 0.362072229385376}],
#  [{'label': 'positive', 'score': 0.43421047925949097}],
#  [{'label': 'positive', 'score': 0.37712326645851135}],
#  [{'label': 'positive', 'score': 0.36948084831237793}],
#  [{'label': 'positive', 'score': 0.3988463282585144}],
#  [{'label': 'positive', 'score': 0.39368128776550293}],
#  [{'label': 'positive', 'score': 0.3697700500488281}],
#  [{'label': 'positive', 'score': 0.4151734709739685}],
#  [{'label': 'positive', 'score': 0.38649842143058777}],
#  [{'label': 'positive', 'score': 0.3835285007953644}],
#  [{'label': 'positive', 'score': 0.3899885416030884}],
#  [{'label': 'positive', 'score': 0.4124130606651306}],
#  [{'label': 'positive', 'score': 0.4069673418998718}],
#  [{'label': 'positive', 'score': 0.375068336725235}],
#  [{'label': 'positive', 'score': 0.41678664088249207}],
#  [{'label': 'positive', 'score': 0.38693124055862427}],
#  [{'label': 'positive', 'score': 0.39305028319358826}],
#  [{'label': 'positive', 'score': 0.3839928209781647}],
#  [{'label': 'positive', 'score': 0.356603741645813}],
#  [{'label': 'positive', 'score': 0.37965378165245056}],
#  [{'label': 'positive', 'score': 0.36505040526390076}],
#  [{'label': 'positive', 'score': 0.36142948269844055}],
#  [{'label': 'positive', 'score': 0.4135258197784424}],
#  [{'label': 'positive', 'score': 0.38536709547042847}],
#  [{'label': 'positive', 'score': 0.39347198605537415}],
#  [{'label': 'positive', 'score': 0.43021321296691895}],
#  [{'label': 'positive', 'score': 0.38604840636253357}],
#  [{'label': 'positive', 'score': 0.3942660093307495}],
#  [{'label': 'positive', 'score': 0.37791207432746887}],
#  [{'label': 'positive', 'score': 0.4221446216106415}],
#  [{'label': 'positive', 'score': 0.39509105682373047}],
#  [{'label': 'positive', 'score': 0.3955176770687103}],
#  [{'label': 'positive', 'score': 0.3697867691516876}],
#  [{'label': 'positive', 'score': 0.38971227407455444}],
#  [{'label': 'positive', 'score': 0.3953099250793457}],
#  [{'label': 'negative', 'score': 0.35794979333877563}],
#  [{'label': 'negative', 'score': 0.3808895945549011}],
#  [{'label': 'positive', 'score': 0.40370962023735046}],
#  [{'label': 'positive', 'score': 0.40257513523101807}],
#  [{'label': 'positive', 'score': 0.37704259157180786}],
#  [{'label': 'positive', 'score': 0.4118005633354187}],
#  [{'label': 'positive', 'score': 0.4142942428588867}],
#  [{'label': 'positive', 'score': 0.39133158326148987}],
#  [{'label': 'positive', 'score': 0.37126848101615906}],
#  [{'label': 'positive', 'score': 0.4084872603416443}],
#  [{'label': 'positive', 'score': 0.38092949986457825}],
#  [{'label': 'positive', 'score': 0.4088612496852875}],
#  [{'label': 'positive', 'score': 0.4031071364879608}],
#  [{'label': 'positive', 'score': 0.39780476689338684}],
#  [{'label': 'positive', 'score': 0.3894524872303009}],
#  [{'label': 'positive', 'score': 0.3843534588813782}],
#  [{'label': 'positive', 'score': 0.4157882630825043}],
#  [{'label': 'positive', 'score': 0.38838905096054077}],
#  [{'label': 'positive', 'score': 0.4053066670894623}],
#  [{'label': 'positive', 'score': 0.3913259506225586}],
#  [{'label': 'positive', 'score': 0.3891443610191345}],
#  [{'label': 'positive', 'score': 0.4000091850757599}],
#  [{'label': 'positive', 'score': 0.39477667212486267}],
#  [{'label': 'positive', 'score': 0.3698805272579193}],
#  [{'label': 'positive', 'score': 0.38908228278160095}],
#  [{'label': 'positive', 'score': 0.4231123626232147}],
#  [{'label': 'positive', 'score': 0.3891350030899048}],
#  [{'label': 'positive', 'score': 0.4049900770187378}],
#  [{'label': 'positive', 'score': 0.40851742029190063}],
#  [{'label': 'positive', 'score': 0.3567606508731842}],
#  [{'label': 'positive', 'score': 0.386944055557251}],
#  [{'label': 'positive', 'score': 0.4082604646682739}],
#  [{'label': 'positive', 'score': 0.37090742588043213}],
#  [{'label': 'positive', 'score': 0.40128451585769653}],
#  [{'label': 'negative', 'score': 0.3620533347129822}],
#  [{'label': 'positive', 'score': 0.39087975025177}],
#  [{'label': 'negative', 'score': 0.384753555059433}],
#  [{'label': 'positive', 'score': 0.3813861012458801}],
#  [{'label': 'positive', 'score': 0.3790804445743561}],
#  [{'label': 'positive', 'score': 0.3858267366886139}],
#  [{'label': 'positive', 'score': 0.3901408016681671}],
#  [{'label': 'positive', 'score': 0.4006660580635071}],
#  [{'label': 'positive', 'score': 0.3732631802558899}],
#  [{'label': 'positive', 'score': 0.41498059034347534}],
#  [{'label': 'positive', 'score': 0.3822340667247772}],
#  [{'label': 'negative', 'score': 0.36085641384124756}],
#  [{'label': 'positive', 'score': 0.38492581248283386}],
#  [{'label': 'positive', 'score': 0.3895527124404907}],
#  [{'label': 'positive', 'score': 0.40296465158462524}],
#  [{'label': 'positive', 'score': 0.37763768434524536}],
#  [{'label': 'positive', 'score': 0.3743703067302704}],
#  [{'label': 'positive', 'score': 0.39323940873146057}],
#  [{'label': 'positive', 'score': 0.35735172033309937}],
#  [{'label': 'positive', 'score': 0.38548052310943604}],
#  [{'label': 'positive', 'score': 0.3935675024986267}],
#  [{'label': 'positive', 'score': 0.382020503282547}],
#  [{'label': 'positive', 'score': 0.3945731222629547}],
#  [{'label': 'positive', 'score': 0.39714884757995605}],
#  [{'label': 'positive', 'score': 0.35900959372520447}],
#  [{'label': 'positive', 'score': 0.3876718580722809}],
#  [{'label': 'positive', 'score': 0.3959260880947113}],
#  [{'label': 'positive', 'score': 0.3708783984184265}],
#  [{'label': 'positive', 'score': 0.40304213762283325}],
#  [{'label': 'positive', 'score': 0.4130784869194031}],
#  [{'label': 'positive', 'score': 0.3986687958240509}],
#  [{'label': 'positive', 'score': 0.3836502134799957}],
#  [{'label': 'positive', 'score': 0.4129425883293152}],
#  [{'label': 'positive', 'score': 0.3919230103492737}],
#  [{'label': 'positive', 'score': 0.4130743741989136}],
#  [{'label': 'positive', 'score': 0.41190582513809204}],
#  [{'label': 'negative', 'score': 0.3637283146381378}],
#  [{'label': 'positive', 'score': 0.3726469576358795}],
#  [{'label': 'positive', 'score': 0.4032462239265442}],
#  [{'label': 'positive', 'score': 0.3696814477443695}],
#  [{'label': 'positive', 'score': 0.39104071259498596}],
#  [{'label': 'positive', 'score': 0.3781302273273468}],
#  [{'label': 'positive', 'score': 0.41800084710121155}],
#  [{'label': 'positive', 'score': 0.4197782576084137}],
#  [{'label': 'positive', 'score': 0.40410947799682617}],
#  [{'label': 'positive', 'score': 0.42988890409469604}],
#  [{'label': 'positive', 'score': 0.425799161195755}],
#  [{'label': 'positive', 'score': 0.40792781114578247}],
#  [{'label': 'negative', 'score': 0.3644827604293823}],
#  [{'label': 'positive', 'score': 0.36597052216529846}],
#  [{'label': 'positive', 'score': 0.36809787154197693}],
#  [{'label': 'positive', 'score': 0.41420838236808777}],
#  [{'label': 'negative', 'score': 0.37222376465797424}],
#  [{'label': 'positive', 'score': 0.39248162508010864}],
#  [{'label': 'positive', 'score': 0.4170147180557251}],
#  [{'label': 'positive', 'score': 0.4006578326225281}],
#  [{'label': 'positive', 'score': 0.3979997932910919}],
#  [{'label': 'positive', 'score': 0.4095352590084076}],
#  [{'label': 'positive', 'score': 0.39084768295288086}],
#  [{'label': 'positive', 'score': 0.3945148289203644}],
#  [{'label': 'positive', 'score': 0.40016883611679077}],
#  [{'label': 'positive', 'score': 0.39264434576034546}],
#  [{'label': 'positive', 'score': 0.3941434919834137}],
#  [{'label': 'positive', 'score': 0.4226328730583191}],
#  [{'label': 'positive', 'score': 0.39030325412750244}],
#  [{'label': 'positive', 'score': 0.3957820236682892}],
#  [{'label': 'positive', 'score': 0.3741469085216522}],
#  [{'label': 'positive', 'score': 0.43279579281806946}],
#  [{'label': 'positive', 'score': 0.3709351420402527}],
#  [{'label': 'positive', 'score': 0.3976278603076935}],
#  [{'label': 'positive', 'score': 0.39088040590286255}],
#  [{'label': 'positive', 'score': 0.3966173529624939}],
#  [{'label': 'positive', 'score': 0.3861401379108429}],
#  [{'label': 'positive', 'score': 0.431606262922287}],
#  [{'label': 'negative', 'score': 0.3913685083389282}],
#  [{'label': 'positive', 'score': 0.40861448645591736}],
#  [{'label': 'positive', 'score': 0.3992285430431366}],
#  [{'label': 'positive', 'score': 0.4019377827644348}],
#  [{'label': 'positive', 'score': 0.3851928412914276}],
#  [{'label': 'positive', 'score': 0.36227068305015564}],
#  [{'label': 'positive', 'score': 0.4185263514518738}],
#  [{'label': 'positive', 'score': 0.38667333126068115}],
#  [{'label': 'negative', 'score': 0.3795646131038666}],
#  [{'label': 'positive', 'score': 0.4141281843185425}],
#  [{'label': 'positive', 'score': 0.3986288011074066}],
#  [{'label': 'positive', 'score': 0.39216527342796326}],
#  [{'label': 'positive', 'score': 0.41585034132003784}],
#  [{'label': 'positive', 'score': 0.3806598484516144}],
#  [{'label': 'positive', 'score': 0.38531774282455444}],
#  [{'label': 'positive', 'score': 0.38481831550598145}],
#  [{'label': 'positive', 'score': 0.3538672924041748}],
#  [{'label': 'positive', 'score': 0.36590322852134705}],
#  [{'label': 'positive', 'score': 0.3757174611091614}],
#  [{'label': 'positive', 'score': 0.3932536244392395}],
#  [{'label': 'positive', 'score': 0.3957824110984802}],
#  [{'label': 'positive', 'score': 0.41752150654792786}],
#  [{'label': 'negative', 'score': 0.36733123660087585}],
#  [{'label': 'positive', 'score': 0.3842170238494873}],
#  [{'label': 'positive', 'score': 0.39537718892097473}],
#  [{'label': 'positive', 'score': 0.4100997745990753}],
#  [{'label': 'positive', 'score': 0.3796573579311371}],
#  [{'label': 'positive', 'score': 0.4040449857711792}],
#  [{'label': 'positive', 'score': 0.40439483523368835}],
#  [{'label': 'positive', 'score': 0.38115426898002625}],
#  [{'label': 'positive', 'score': 0.3906843960285187}],
#  [{'label': 'positive', 'score': 0.4201206564903259}],
#  [{'label': 'positive', 'score': 0.42757436633110046}],
#  [{'label': 'positive', 'score': 0.38050827383995056}],
#  [{'label': 'positive', 'score': 0.3962527811527252}],
#  [{'label': 'positive', 'score': 0.42429548501968384}],
#  [{'label': 'positive', 'score': 0.3998817801475525}],
#  [{'label': 'positive', 'score': 0.38603341579437256}],
#  [{'label': 'positive', 'score': 0.41311749815940857}],
#  [{'label': 'positive', 'score': 0.39945292472839355}],
#  [{'label': 'positive', 'score': 0.3941335380077362}],
#  [{'label': 'positive', 'score': 0.3843314051628113}],
#  [{'label': 'negative', 'score': 0.3728815019130707}],
#  [{'label': 'positive', 'score': 0.3839721381664276}],
#  [{'label': 'positive', 'score': 0.4125571846961975}],
#  [{'label': 'positive', 'score': 0.3845359981060028}],
#  [{'label': 'positive', 'score': 0.38692060112953186}],
#  [{'label': 'positive', 'score': 0.4164954423904419}],
#  [{'label': 'positive', 'score': 0.3925822079181671}],
#  [{'label': 'positive', 'score': 0.37983375787734985}],
#  [{'label': 'positive', 'score': 0.4045041501522064}],
#  [{'label': 'positive', 'score': 0.3929288685321808}],
#  [{'label': 'positive', 'score': 0.400715172290802}],
#  [{'label': 'positive', 'score': 0.3804987967014313}],
#  [{'label': 'positive', 'score': 0.37911099195480347}],
#  [{'label': 'positive', 'score': 0.37392139434814453}],
#  [{'label': 'positive', 'score': 0.3921164274215698}],
#  [{'label': 'positive', 'score': 0.38317668437957764}],
#  [{'label': 'positive', 'score': 0.39537855982780457}],
#  [{'label': 'negative', 'score': 0.3766852021217346}],
#  [{'label': 'positive', 'score': 0.36162328720092773}],
#  [{'label': 'positive', 'score': 0.3909401595592499}],
#  [{'label': 'positive', 'score': 0.4079994261264801}],
#  [{'label': 'positive', 'score': 0.4023137092590332}],
#  [{'label': 'positive', 'score': 0.42050600051879883}],
#  [{'label': 'positive', 'score': 0.36245694756507874}],
#  [{'label': 'positive', 'score': 0.3971790671348572}],
#  [{'label': 'positive', 'score': 0.3953014612197876}],
#  [{'label': 'negative', 'score': 0.36748868227005005}],
#  [{'label': 'positive', 'score': 0.39020317792892456}],
#  [{'label': 'positive', 'score': 0.40306800603866577}],
#  [{'label': 'positive', 'score': 0.39559534192085266}],
#  [{'label': 'positive', 'score': 0.40486204624176025}],
#  [{'label': 'positive', 'score': 0.3816721737384796}],
#  [{'label': 'positive', 'score': 0.41761302947998047}],
#  [{'label': 'positive', 'score': 0.3863229751586914}],
#  [{'label': 'positive', 'score': 0.4055232107639313}],
#  [{'label': 'positive', 'score': 0.3774126470088959}],
#  [{'label': 'positive', 'score': 0.4115673303604126}],
#  [{'label': 'positive', 'score': 0.38496530055999756}],
#  [{'label': 'positive', 'score': 0.3745274841785431}],
#  [{'label': 'positive', 'score': 0.40283867716789246}],
#  [{'label': 'positive', 'score': 0.40375587344169617}],
#  [{'label': 'positive', 'score': 0.36954644322395325}],
#  [{'label': 'positive', 'score': 0.40960437059402466}],
#  [{'label': 'positive', 'score': 0.37139248847961426}],
#  [{'label': 'positive', 'score': 0.3681803047657013}],
#  [{'label': 'positive', 'score': 0.39999881386756897}],
#  [{'label': 'positive', 'score': 0.3826829195022583}],
#  [{'label': 'negative', 'score': 0.3725813627243042}],
#  [{'label': 'positive', 'score': 0.3886079490184784}],
#  [{'label': 'positive', 'score': 0.39042624831199646}],
#  [{'label': 'positive', 'score': 0.4050538241863251}],
#  [{'label': 'positive', 'score': 0.3682740330696106}],
#  [{'label': 'positive', 'score': 0.39719367027282715}],
#  [{'label': 'positive', 'score': 0.4019169509410858}],
#  [{'label': 'positive', 'score': 0.38752955198287964}],
#  [{'label': 'positive', 'score': 0.3906114995479584}],
#  [{'label': 'positive', 'score': 0.4295644760131836}],
#  [{'label': 'positive', 'score': 0.37859806418418884}],
#  [{'label': 'positive', 'score': 0.3903070390224457}],
#  [{'label': 'positive', 'score': 0.4167320728302002}],
#  [{'label': 'positive', 'score': 0.42336755990982056}],
#  [{'label': 'positive', 'score': 0.3859144151210785}],
#  [{'label': 'positive', 'score': 0.4102155566215515}],
#  [{'label': 'positive', 'score': 0.38922789692878723}],
#  [{'label': 'positive', 'score': 0.4021463990211487}],
#  [{'label': 'positive', 'score': 0.41184327006340027}],
#  [{'label': 'positive', 'score': 0.39521506428718567}],
#  [{'label': 'positive', 'score': 0.40493881702423096}],
#  [{'label': 'positive', 'score': 0.3943714201450348}],
#  [{'label': 'positive', 'score': 0.41034069657325745}],
#  [{'label': 'positive', 'score': 0.3987502455711365}],
#  [{'label': 'positive', 'score': 0.4151470363140106}],
#  [{'label': 'positive', 'score': 0.3875291645526886}],
#  [{'label': 'positive', 'score': 0.3980863392353058}],
#  [{'label': 'positive', 'score': 0.3800748586654663}],
#  [{'label': 'positive', 'score': 0.4107968807220459}],
#  [{'label': 'positive', 'score': 0.4077914357185364}],
#  [{'label': 'positive', 'score': 0.35967010259628296}],
#  [{'label': 'positive', 'score': 0.3977987468242645}],
#  [{'label': 'positive', 'score': 0.41336628794670105}],
#  [{'label': 'positive', 'score': 0.41611579060554504}],
#  [{'label': 'positive', 'score': 0.40504634380340576}],
#  [{'label': 'positive', 'score': 0.40354135632514954}],
#  [{'label': 'positive', 'score': 0.4133208990097046}],
#  [{'label': 'positive', 'score': 0.4159178137779236}],
#  [{'label': 'positive', 'score': 0.4183768332004547}],
#  [{'label': 'positive', 'score': 0.3923114836215973}],
#  [{'label': 'positive', 'score': 0.37476685643196106}],
#  [{'label': 'positive', 'score': 0.3956982493400574}],
#  [{'label': 'positive', 'score': 0.4081157147884369}],
#  [{'label': 'positive', 'score': 0.37447389960289}],
#  [{'label': 'positive', 'score': 0.38528603315353394}],
#  [{'label': 'positive', 'score': 0.3881590962409973}],
#  [{'label': 'positive', 'score': 0.39714401960372925}],
#  [{'label': 'positive', 'score': 0.4176407754421234}],
#  [{'label': 'positive', 'score': 0.3921596109867096}],
#  [{'label': 'positive', 'score': 0.36869344115257263}],
#  [{'label': 'positive', 'score': 0.3999916911125183}],
#  [{'label': 'positive', 'score': 0.40324994921684265}],
#  [{'label': 'positive', 'score': 0.38867321610450745}],
#  [{'label': 'positive', 'score': 0.3929932713508606}],
#  [{'label': 'positive', 'score': 0.4125615656375885}],
#  [{'label': 'positive', 'score': 0.4200463593006134}],
#  [{'label': 'negative', 'score': 0.37477418780326843}],
#  [{'label': 'positive', 'score': 0.3883085548877716}],
#  [{'label': 'positive', 'score': 0.40628233551979065}],
#  [{'label': 'positive', 'score': 0.41262441873550415}],
#  [{'label': 'positive', 'score': 0.365005761384964}],
#  [{'label': 'positive', 'score': 0.4011240601539612}],
#  [{'label': 'positive', 'score': 0.3982187509536743}],
#  [{'label': 'positive', 'score': 0.3949393033981323}],
#  [{'label': 'positive', 'score': 0.4113057851791382}],
#  [{'label': 'positive', 'score': 0.3804894983768463}],
#  [{'label': 'positive', 'score': 0.4145210087299347}],
#  [{'label': 'negative', 'score': 0.3717573583126068}],
#  [{'label': 'positive', 'score': 0.3828980028629303}],
#  [{'label': 'positive', 'score': 0.389566570520401}],
#  [{'label': 'positive', 'score': 0.39664483070373535}],
#  [{'label': 'positive', 'score': 0.40394845604896545}],
#  [{'label': 'positive', 'score': 0.3689062297344208}],
#  [{'label': 'positive', 'score': 0.41798135638237}],
#  [{'label': 'positive', 'score': 0.39498552680015564}],
#  [{'label': 'negative', 'score': 0.3718203902244568}],
#  [{'label': 'positive', 'score': 0.40483176708221436}],
#  [{'label': 'positive', 'score': 0.400656521320343}],
#  [{'label': 'positive', 'score': 0.40812283754348755}],
#  [{'label': 'positive', 'score': 0.3803956210613251}],
#  [{'label': 'negative', 'score': 0.3747338056564331}],
#  [{'label': 'positive', 'score': 0.4088617265224457}],
#  [{'label': 'negative', 'score': 0.39007970690727234}],
#  [{'label': 'positive', 'score': 0.38894763588905334}],
#  [{'label': 'positive', 'score': 0.39764168858528137}],
#  [{'label': 'positive', 'score': 0.4072076082229614}],
#  [{'label': 'positive', 'score': 0.4120062589645386}],
#  [{'label': 'positive', 'score': 0.3838835060596466}],
#  [{'label': 'positive', 'score': 0.3871767520904541}],
#  [{'label': 'positive', 'score': 0.3703598380088806}],
#  [{'label': 'negative', 'score': 0.37147217988967896}],
#  [{'label': 'positive', 'score': 0.3844583332538605}],
#  [{'label': 'positive', 'score': 0.382694274187088}],
#  [{'label': 'positive', 'score': 0.4154549837112427}],
#  [{'label': 'positive', 'score': 0.3766986131668091}],
#  [{'label': 'positive', 'score': 0.4167129397392273}],
#  [{'label': 'positive', 'score': 0.4059070646762848}],
#  [{'label': 'positive', 'score': 0.3741663098335266}],
#  [{'label': 'positive', 'score': 0.41181862354278564}],
#  [{'label': 'positive', 'score': 0.36038509011268616}],
#  [{'label': 'positive', 'score': 0.38491272926330566}],
#  [{'label': 'positive', 'score': 0.4171806573867798}],
#  [{'label': 'positive', 'score': 0.3765435218811035}],
#  [{'label': 'positive', 'score': 0.3627093434333801}],
#  [{'label': 'positive', 'score': 0.41715139150619507}],
#  [{'label': 'positive', 'score': 0.3757137954235077}],
#  [{'label': 'positive', 'score': 0.3715413808822632}],
#  [{'label': 'positive', 'score': 0.3934314250946045}],
#  [{'label': 'positive', 'score': 0.387335866689682}],
#  [{'label': 'positive', 'score': 0.40498390793800354}],
#  [{'label': 'positive', 'score': 0.40835335850715637}],
#  [{'label': 'positive', 'score': 0.39596638083457947}],
#  [{'label': 'positive', 'score': 0.39855197072029114}],
#  [{'label': 'positive', 'score': 0.3974481523036957}],
#  [{'label': 'positive', 'score': 0.3936620056629181}],
#  [{'label': 'positive', 'score': 0.3852402865886688}],
#  [{'label': 'positive', 'score': 0.40104803442955017}],
#  [{'label': 'positive', 'score': 0.40175336599349976}],
#  [{'label': 'negative', 'score': 0.36728957295417786}],
#  [{'label': 'positive', 'score': 0.4108354449272156}],
#  [{'label': 'positive', 'score': 0.3917815387248993}],
#  [{'label': 'positive', 'score': 0.3799925744533539}],
#  [{'label': 'positive', 'score': 0.41770535707473755}],
#  [{'label': 'positive', 'score': 0.3604556620121002}],
#  [{'label': 'positive', 'score': 0.3757694661617279}],
#  [{'label': 'positive', 'score': 0.3765840530395508}],
#  [{'label': 'positive', 'score': 0.39287588000297546}],
#  [{'label': 'positive', 'score': 0.40147292613983154}],
#  [{'label': 'positive', 'score': 0.41101759672164917}],
#  [{'label': 'positive', 'score': 0.4124457538127899}],
#  [{'label': 'positive', 'score': 0.41289061307907104}],
#  [{'label': 'positive', 'score': 0.4250320792198181}],
#  [{'label': 'positive', 'score': 0.3994864523410797}],
#  [{'label': 'positive', 'score': 0.42449241876602173}],
#  [{'label': 'positive', 'score': 0.42950212955474854}],
#  [{'label': 'negative', 'score': 0.3831205368041992}],
#  [{'label': 'positive', 'score': 0.3870576322078705}],
#  [{'label': 'positive', 'score': 0.4197731018066406}],
#  [{'label': 'positive', 'score': 0.39390456676483154}],
#  [{'label': 'positive', 'score': 0.39414167404174805}],
#  [{'label': 'positive', 'score': 0.40220189094543457}],
#  [{'label': 'positive', 'score': 0.42528367042541504}],
#  [{'label': 'positive', 'score': 0.4118732810020447}],
#  [{'label': 'positive', 'score': 0.3929431140422821}],
#  [{'label': 'positive', 'score': 0.415880411863327}],
#  [{'label': 'positive', 'score': 0.38054534792900085}],
#  [{'label': 'positive', 'score': 0.39039313793182373}],
#  [{'label': 'positive', 'score': 0.38598600029945374}],
#  [{'label': 'positive', 'score': 0.37636059522628784}],
#  [{'label': 'positive', 'score': 0.3556181788444519}],
#  [{'label': 'positive', 'score': 0.384626567363739}],
#  [{'label': 'positive', 'score': 0.40081217885017395}],
#  [{'label': 'positive', 'score': 0.41651836037635803}],
#  [{'label': 'positive', 'score': 0.39806267619132996}],
#  [{'label': 'positive', 'score': 0.3860628306865692}],
#  [{'label': 'positive', 'score': 0.4168342351913452}],
#  [{'label': 'positive', 'score': 0.3726925849914551}],
#  [{'label': 'positive', 'score': 0.40744316577911377}],
#  [{'label': 'positive', 'score': 0.41801607608795166}],
#  [{'label': 'positive', 'score': 0.3828105628490448}],
#  [{'label': 'positive', 'score': 0.3950202167034149}],
#  [{'label': 'positive', 'score': 0.3923788368701935}],
#  [{'label': 'positive', 'score': 0.3950704336166382}],
#  [{'label': 'positive', 'score': 0.40742143988609314}],
#  [{'label': 'positive', 'score': 0.38959091901779175}],
#  [{'label': 'positive', 'score': 0.40176334977149963}],
#  [{'label': 'positive', 'score': 0.3888264298439026}],
#  [{'label': 'positive', 'score': 0.41477692127227783}],
#  [{'label': 'positive', 'score': 0.388421893119812}],
#  [{'label': 'positive', 'score': 0.3685489594936371}],
#  [{'label': 'positive', 'score': 0.41321271657943726}],
#  [{'label': 'positive', 'score': 0.4330512583255768}],
#  [{'label': 'positive', 'score': 0.3712659180164337}],
#  [{'label': 'positive', 'score': 0.3902895748615265}],
#  [{'label': 'positive', 'score': 0.39313167333602905}],
#  [{'label': 'positive', 'score': 0.3799223303794861}],
#  [{'label': 'positive', 'score': 0.3975619375705719}],
#  [{'label': 'positive', 'score': 0.43472525477409363}],
#  [{'label': 'positive', 'score': 0.41163188219070435}],
#  [{'label': 'positive', 'score': 0.38025590777397156}],
#  [{'label': 'positive', 'score': 0.3935896158218384}],
#  [{'label': 'positive', 'score': 0.39942821860313416}],
#  [{'label': 'positive', 'score': 0.41667839884757996}],
#  [{'label': 'positive', 'score': 0.43714138865470886}],
#  [{'label': 'positive', 'score': 0.3889895975589752}],
#  [{'label': 'positive', 'score': 0.39372408390045166}],
#  [{'label': 'positive', 'score': 0.3696170449256897}],
#  [{'label': 'positive', 'score': 0.39460650086402893}],
#  [{'label': 'positive', 'score': 0.4055835008621216}],
#  [{'label': 'positive', 'score': 0.4090530574321747}],
#  [{'label': 'positive', 'score': 0.41235706210136414}],
#  [{'label': 'negative', 'score': 0.3739984333515167}],
#  [{'label': 'positive', 'score': 0.3958216905593872}],
#  [{'label': 'positive', 'score': 0.40783944725990295}],
#  [{'label': 'positive', 'score': 0.39305081963539124}],
#  [{'label': 'positive', 'score': 0.3961644470691681}],
#  [{'label': 'positive', 'score': 0.41474682092666626}],
#  [{'label': 'positive', 'score': 0.40387943387031555}],
#  [{'label': 'positive', 'score': 0.3779122829437256}],
#  [{'label': 'positive', 'score': 0.40609344840049744}],
#  [{'label': 'positive', 'score': 0.4223223030567169}],
#  [{'label': 'positive', 'score': 0.3927907645702362}],
#  [{'label': 'positive', 'score': 0.3858155906200409}],
#  [{'label': 'positive', 'score': 0.39089396595954895}],
#  [{'label': 'positive', 'score': 0.4289558231830597}],
#  [{'label': 'positive', 'score': 0.4041293263435364}],
#  [{'label': 'positive', 'score': 0.374533087015152}],
#  [{'label': 'positive', 'score': 0.42133158445358276}],
#  [{'label': 'positive', 'score': 0.3937559425830841}],
#  [{'label': 'positive', 'score': 0.38224396109580994}],
#  [{'label': 'positive', 'score': 0.38473498821258545}],
#  [{'label': 'positive', 'score': 0.3933621048927307}],
#  [{'label': 'positive', 'score': 0.41659054160118103}],
#  [{'label': 'positive', 'score': 0.36226463317871094}],
#  [{'label': 'positive', 'score': 0.39994361996650696}],
#  [{'label': 'positive', 'score': 0.39158523082733154}],
#  [{'label': 'positive', 'score': 0.4211978614330292}],
#  [{'label': 'positive', 'score': 0.39878028631210327}],
#  [{'label': 'positive', 'score': 0.40373846888542175}],
#  [{'label': 'positive', 'score': 0.40564414858818054}],
#  [{'label': 'positive', 'score': 0.4123365581035614}],
#  [{'label': 'positive', 'score': 0.4109908938407898}],
#  [{'label': 'positive', 'score': 0.38270336389541626}],
#  [{'label': 'positive', 'score': 0.39900076389312744}],
#  [{'label': 'positive', 'score': 0.4005540609359741}],
#  [{'label': 'positive', 'score': 0.3814569413661957}],
#  [{'label': 'positive', 'score': 0.36333325505256653}],
#  [{'label': 'positive', 'score': 0.3801279664039612}],
#  [{'label': 'positive', 'score': 0.40264230966567993}],
#  [{'label': 'positive', 'score': 0.3940630555152893}],
#  [{'label': 'positive', 'score': 0.40112122893333435}],
#  [{'label': 'positive', 'score': 0.4042455554008484}],
#  [{'label': 'positive', 'score': 0.38585469126701355}],
#  [{'label': 'positive', 'score': 0.3994654715061188}],
#  [{'label': 'positive', 'score': 0.377299040555954}],
#  [{'label': 'positive', 'score': 0.3871791362762451}],
#  [{'label': 'positive', 'score': 0.38843899965286255}],
#  [{'label': 'positive', 'score': 0.38302427530288696}],
#  [{'label': 'negative', 'score': 0.3730117678642273}],
#  [{'label': 'positive', 'score': 0.41961923241615295}],
#  [{'label': 'positive', 'score': 0.3857613205909729}],
#  [{'label': 'positive', 'score': 0.4198554754257202}],
#  [{'label': 'positive', 'score': 0.418963760137558}],
#  [{'label': 'positive', 'score': 0.36113470792770386}],
#  [{'label': 'positive', 'score': 0.38402172923088074}],
#  [{'label': 'negative', 'score': 0.3745148777961731}],
#  [{'label': 'positive', 'score': 0.38942521810531616}],
#  [{'label': 'positive', 'score': 0.42288145422935486}],
#  [{'label': 'positive', 'score': 0.4291272461414337}],
#  [{'label': 'positive', 'score': 0.3853950798511505}],
#  [{'label': 'positive', 'score': 0.41264787316322327}],
#  [{'label': 'positive', 'score': 0.39156344532966614}],
#  [{'label': 'positive', 'score': 0.3858697712421417}],
#  [{'label': 'positive', 'score': 0.4056912958621979}],
#  [{'label': 'positive', 'score': 0.38197004795074463}],
#  [{'label': 'positive', 'score': 0.39406266808509827}],
#  [{'label': 'positive', 'score': 0.40426433086395264}],
#  [{'label': 'positive', 'score': 0.3981797397136688}],
#  [{'label': 'negative', 'score': 0.38386794924736023}],
#  [{'label': 'positive', 'score': 0.4258362650871277}],
#  [{'label': 'positive', 'score': 0.3788517415523529}],
#  [{'label': 'positive', 'score': 0.3984728753566742}],
#  [{'label': 'positive', 'score': 0.4027843177318573}],
#  [{'label': 'positive', 'score': 0.39816489815711975}],
#  [{'label': 'positive', 'score': 0.3992841839790344}],
#  [{'label': 'positive', 'score': 0.37082698941230774}],
#  [{'label': 'positive', 'score': 0.40356045961380005}],
#  [{'label': 'positive', 'score': 0.40400657057762146}],
#  [{'label': 'positive', 'score': 0.4150831401348114}],
#  [{'label': 'positive', 'score': 0.40473198890686035}],
#  [{'label': 'positive', 'score': 0.43418002128601074}],
#  [{'label': 'positive', 'score': 0.39628949761390686}],
#  [{'label': 'positive', 'score': 0.42535150051116943}],
#  [{'label': 'positive', 'score': 0.39316728711128235}],
#  [{'label': 'positive', 'score': 0.39078599214553833}],
#  [{'label': 'positive', 'score': 0.39582493901252747}],
#  [{'label': 'positive', 'score': 0.40994375944137573}],
#  [{'label': 'positive', 'score': 0.405569463968277}],
#  [{'label': 'positive', 'score': 0.39941370487213135}],
#  [{'label': 'positive', 'score': 0.41355079412460327}],
#  [{'label': 'positive', 'score': 0.40822523832321167}],
#  [{'label': 'positive', 'score': 0.38657253980636597}],
#  [{'label': 'positive', 'score': 0.40957027673721313}],
#  [{'label': 'positive', 'score': 0.41525986790657043}],
#  [{'label': 'positive', 'score': 0.4099724292755127}],
#  [{'label': 'positive', 'score': 0.4033307731151581}],
#  [{'label': 'positive', 'score': 0.38562485575675964}],
#  [{'label': 'positive', 'score': 0.39202606678009033}],
#  [{'label': 'positive', 'score': 0.4086335599422455}],
#  [{'label': 'positive', 'score': 0.3838048577308655}],
#  [{'label': 'positive', 'score': 0.3928057849407196}],
#  [{'label': 'positive', 'score': 0.36476343870162964}],
#  [{'label': 'positive', 'score': 0.3682059049606323}],
#  [{'label': 'negative', 'score': 0.37468159198760986}],
#  [{'label': 'positive', 'score': 0.3828812539577484}],
#  [{'label': 'positive', 'score': 0.38144367933273315}],
#  [{'label': 'positive', 'score': 0.4140251874923706}],
#  [{'label': 'negative', 'score': 0.36868491768836975}],
#  [{'label': 'positive', 'score': 0.3787817358970642}],
#  [{'label': 'positive', 'score': 0.40045827627182007}],
#  [{'label': 'negative', 'score': 0.3744407892227173}],
#  [{'label': 'positive', 'score': 0.4188258647918701}],
#  [{'label': 'positive', 'score': 0.42271339893341064}],
#  [{'label': 'positive', 'score': 0.3726523518562317}],
#  [{'label': 'positive', 'score': 0.40458473563194275}],
#  [{'label': 'positive', 'score': 0.40141022205352783}],
#  [{'label': 'positive', 'score': 0.3760659396648407}],
#  [{'label': 'positive', 'score': 0.38005441427230835}],
#  [{'label': 'positive', 'score': 0.41984421014785767}],
#  [{'label': 'positive', 'score': 0.392210990190506}],
#  [{'label': 'positive', 'score': 0.3995390236377716}],
#  [{'label': 'positive', 'score': 0.41722410917282104}],
#  [{'label': 'positive', 'score': 0.36027899384498596}],
#  [{'label': 'positive', 'score': 0.3959156274795532}],
#  [{'label': 'positive', 'score': 0.3859664797782898}],
#  [{'label': 'positive', 'score': 0.3981464207172394}],
#  [{'label': 'positive', 'score': 0.37235963344573975}],
#  [{'label': 'positive', 'score': 0.40598970651626587}],
#  [{'label': 'positive', 'score': 0.4127073884010315}],
#  [{'label': 'positive', 'score': 0.3549680709838867}],
#  [{'label': 'positive', 'score': 0.37453556060791016}],
#  [{'label': 'positive', 'score': 0.40342965722084045}],
#  [{'label': 'positive', 'score': 0.398714542388916}],
#  [{'label': 'positive', 'score': 0.37101733684539795}],
#  [{'label': 'positive', 'score': 0.4064573347568512}],
#  [{'label': 'positive', 'score': 0.40221914649009705}],
#  [{'label': 'positive', 'score': 0.41248777508735657}],
#  [{'label': 'positive', 'score': 0.4055987596511841}],
#  [{'label': 'positive', 'score': 0.3788512051105499}],
#  [{'label': 'positive', 'score': 0.4042716324329376}],
#  [{'label': 'positive', 'score': 0.39415937662124634}],
#  [{'label': 'negative', 'score': 0.3865942656993866}],
#  [{'label': 'positive', 'score': 0.409747838973999}],
#  [{'label': 'positive', 'score': 0.39903879165649414}],
#  [{'label': 'positive', 'score': 0.3762161135673523}],
#  [{'label': 'negative', 'score': 0.3733128607273102}],
#  [{'label': 'positive', 'score': 0.39820215106010437}],
#  [{'label': 'negative', 'score': 0.37548398971557617}],
#  [{'label': 'positive', 'score': 0.40256986021995544}],
#  [{'label': 'positive', 'score': 0.385850191116333}],
#  [{'label': 'positive', 'score': 0.4108412563800812}],
#  [{'label': 'positive', 'score': 0.4105890095233917}],
#  [{'label': 'positive', 'score': 0.38537099957466125}],
#  [{'label': 'positive', 'score': 0.4073264002799988}],
#  [{'label': 'positive', 'score': 0.4245421886444092}],
#  [{'label': 'positive', 'score': 0.3907775580883026}],
#  [{'label': 'positive', 'score': 0.39516496658325195}],
#  [{'label': 'positive', 'score': 0.4119178354740143}],
#  [{'label': 'positive', 'score': 0.36402207612991333}],
#  [{'label': 'positive', 'score': 0.3851550221443176}],
#  [{'label': 'positive', 'score': 0.3776475489139557}],
#  [{'label': 'negative', 'score': 0.3742588460445404}],
#  [{'label': 'negative', 'score': 0.3759234845638275}],
#  [{'label': 'positive', 'score': 0.41340142488479614}],
#  [{'label': 'positive', 'score': 0.3907543122768402}],
#  [{'label': 'negative', 'score': 0.37776702642440796}],
#  [{'label': 'positive', 'score': 0.39331015944480896}],
#  [{'label': 'negative', 'score': 0.38395994901657104}],
#  [{'label': 'positive', 'score': 0.393333375453949}],
#  [{'label': 'negative', 'score': 0.38243430852890015}],
#  [{'label': 'positive', 'score': 0.3900832533836365}],
#  [{'label': 'positive', 'score': 0.4052293002605438}],
#  [{'label': 'positive', 'score': 0.37070831656455994}],
#  [{'label': 'positive', 'score': 0.41207656264305115}],
#  [{'label': 'positive', 'score': 0.39516690373420715}],
#  [{'label': 'positive', 'score': 0.40597304701805115}],
#  [{'label': 'positive', 'score': 0.4211626946926117}],
#  [{'label': 'positive', 'score': 0.39137813448905945}],
#  [{'label': 'negative', 'score': 0.36398348212242126}],
#  [{'label': 'positive', 'score': 0.36691296100616455}],
#  [{'label': 'positive', 'score': 0.40605950355529785}],
#  [{'label': 'positive', 'score': 0.3905589282512665}],
#  [{'label': 'positive', 'score': 0.364404559135437}],
#  [{'label': 'positive', 'score': 0.39346280694007874}],
#  [{'label': 'positive', 'score': 0.39688819646835327}],
#  [{'label': 'positive', 'score': 0.413533091545105}],
#  [{'label': 'positive', 'score': 0.4123813211917877}],
#  [{'label': 'positive', 'score': 0.37938717007637024}],
#  [{'label': 'positive', 'score': 0.3972625434398651}],
#  [{'label': 'positive', 'score': 0.4002837836742401}],
#  [{'label': 'positive', 'score': 0.39722368121147156}],
#  [{'label': 'positive', 'score': 0.3955289125442505}],
#  [{'label': 'negative', 'score': 0.37443169951438904}],
#  [{'label': 'positive', 'score': 0.40680113434791565}],
#  [{'label': 'positive', 'score': 0.39602407813072205}],
#  [{'label': 'negative', 'score': 0.36504289507865906}],
#  [{'label': 'positive', 'score': 0.39067548513412476}],
#  [{'label': 'positive', 'score': 0.3936218023300171}],
#  [{'label': 'positive', 'score': 0.4239829480648041}],
#  [{'label': 'positive', 'score': 0.37348759174346924}],
#  [{'label': 'positive', 'score': 0.3970514237880707}],
#  [{'label': 'positive', 'score': 0.4138791561126709}],
#  [{'label': 'positive', 'score': 0.4119093418121338}],
#  [{'label': 'positive', 'score': 0.3742884397506714}],
#  [{'label': 'positive', 'score': 0.39464399218559265}],
#  [{'label': 'positive', 'score': 0.40138277411460876}],
#  [{'label': 'positive', 'score': 0.3828767240047455}],
#  [{'label': 'positive', 'score': 0.3841594159603119}],
#  [{'label': 'positive', 'score': 0.39258822798728943}],
#  [{'label': 'negative', 'score': 0.35921385884284973}],
#  [{'label': 'positive', 'score': 0.38757142424583435}],
#  [{'label': 'positive', 'score': 0.42802754044532776}],
#  [{'label': 'positive', 'score': 0.40590688586235046}],
#  [{'label': 'positive', 'score': 0.4169449508190155}],
#  [{'label': 'positive', 'score': 0.385812908411026}],
#  [{'label': 'positive', 'score': 0.38153448700904846}],
#  [{'label': 'negative', 'score': 0.3929898142814636}],
#  [{'label': 'positive', 'score': 0.4156956374645233}],
#  [{'label': 'positive', 'score': 0.42295506596565247}],
#  [{'label': 'positive', 'score': 0.40337249636650085}],
#  [{'label': 'positive', 'score': 0.4164992570877075}],
#  [{'label': 'positive', 'score': 0.3981497287750244}],
#  [{'label': 'positive', 'score': 0.38735443353652954}],
#  [{'label': 'positive', 'score': 0.3642463982105255}],
#  [{'label': 'positive', 'score': 0.3938522934913635}],
#  [{'label': 'positive', 'score': 0.40833765268325806}],
#  [{'label': 'positive', 'score': 0.4070597290992737}],
#  [{'label': 'positive', 'score': 0.38815316557884216}],
#  [{'label': 'positive', 'score': 0.40670162439346313}],
#  [{'label': 'positive', 'score': 0.3619682192802429}],
#  [{'label': 'positive', 'score': 0.3789251148700714}],
#  [{'label': 'positive', 'score': 0.3858371376991272}],
#  [{'label': 'positive', 'score': 0.3740125596523285}],
#  [{'label': 'positive', 'score': 0.4031996428966522}],
#  [{'label': 'negative', 'score': 0.35921427607536316}],
#  [{'label': 'positive', 'score': 0.3724449574947357}],
#  [{'label': 'positive', 'score': 0.40513646602630615}],
#  [{'label': 'positive', 'score': 0.41262906789779663}],
#  [{'label': 'positive', 'score': 0.40699025988578796}],
#  [{'label': 'negative', 'score': 0.36110350489616394}],
#  [{'label': 'positive', 'score': 0.40858954191207886}],
#  [{'label': 'positive', 'score': 0.41106849908828735}],
#  [{'label': 'positive', 'score': 0.3697988986968994}],
#  [{'label': 'positive', 'score': 0.3849611282348633}],
#  [{'label': 'positive', 'score': 0.40363427996635437}],
#  [{'label': 'positive', 'score': 0.40057888627052307}],
#  [{'label': 'positive', 'score': 0.3965798020362854}],
#  [{'label': 'positive', 'score': 0.38812342286109924}],
#  [{'label': 'positive', 'score': 0.4060317575931549}],
#  [{'label': 'positive', 'score': 0.40013325214385986}],
#  [{'label': 'negative', 'score': 0.3763292133808136}],
#  [{'label': 'positive', 'score': 0.3680351972579956}],
#  [{'label': 'positive', 'score': 0.38740774989128113}],
#  [{'label': 'positive', 'score': 0.4029516875743866}],
#  [{'label': 'positive', 'score': 0.4010135233402252}],
#  [{'label': 'positive', 'score': 0.42601433396339417}],
#  [{'label': 'positive', 'score': 0.4129107892513275}],
#  [{'label': 'positive', 'score': 0.37438011169433594}],
#  [{'label': 'positive', 'score': 0.35888588428497314}],
#  [{'label': 'positive', 'score': 0.37062838673591614}],
#  [{'label': 'positive', 'score': 0.4211627244949341}],
#  [{'label': 'positive', 'score': 0.4110513925552368}],
#  [{'label': 'positive', 'score': 0.3944142758846283}],
#  [{'label': 'positive', 'score': 0.42030268907546997}],
#  [{'label': 'positive', 'score': 0.3703892230987549}],
#  [{'label': 'positive', 'score': 0.4139235317707062}],
#  [{'label': 'positive', 'score': 0.3987036943435669}],
#  [{'label': 'positive', 'score': 0.376200795173645}],
#  [{'label': 'positive', 'score': 0.3957490026950836}],
#  [{'label': 'positive', 'score': 0.40201374888420105}],
#  [{'label': 'positive', 'score': 0.3787645697593689}],
#  [{'label': 'positive', 'score': 0.39650779962539673}],
#  [{'label': 'positive', 'score': 0.4216805696487427}],
#  [{'label': 'positive', 'score': 0.4086105227470398}],
#  [{'label': 'positive', 'score': 0.4327761232852936}],
#  [{'label': 'positive', 'score': 0.4061853587627411}],
#  [{'label': 'positive', 'score': 0.38684549927711487}],
#  [{'label': 'negative', 'score': 0.36392509937286377}],
#  [{'label': 'negative', 'score': 0.36265426874160767}],
#  [{'label': 'positive', 'score': 0.38821539282798767}],
#  [{'label': 'positive', 'score': 0.3933614194393158}],
#  [{'label': 'positive', 'score': 0.41904088854789734}],
#  [{'label': 'positive', 'score': 0.39128145575523376}],
#  [{'label': 'positive', 'score': 0.4138762950897217}],
#  [{'label': 'positive', 'score': 0.4161849021911621}],
#  [{'label': 'negative', 'score': 0.36560627818107605}],
#  [{'label': 'positive', 'score': 0.3869644105434418}],
#  [{'label': 'positive', 'score': 0.41561922430992126}],
#  [{'label': 'positive', 'score': 0.3862389922142029}],
#  [{'label': 'positive', 'score': 0.37610143423080444}],
#  [{'label': 'positive', 'score': 0.39159321784973145}],
#  [{'label': 'positive', 'score': 0.4149380624294281}],
#  [{'label': 'positive', 'score': 0.39200061559677124}],
#  [{'label': 'positive', 'score': 0.40717169642448425}],
#  [{'label': 'positive', 'score': 0.4137818515300751}],
#  [{'label': 'positive', 'score': 0.3926061689853668}],
#  [{'label': 'positive', 'score': 0.4068347215652466}],
#  [{'label': 'positive', 'score': 0.3909178078174591}],
#  [{'label': 'positive', 'score': 0.3590628206729889}],
#  [{'label': 'positive', 'score': 0.4100547432899475}],
#  [{'label': 'positive', 'score': 0.3962461054325104}],
#  [{'label': 'positive', 'score': 0.3814319670200348}],
#  [{'label': 'positive', 'score': 0.37380659580230713}],
#  [{'label': 'positive', 'score': 0.39759209752082825}]]
